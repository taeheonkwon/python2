# %% [markdown]
# <a href="https://colab.research.google.com/github/taeheonkwon/python2/blob/main/Lecture8_e.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Set
#
# Sets are written with curly brackets.
#
#
# A set is a collection which is both unordered and unindexed.
#
# Set items can appear in a different order every time you use them, and cannot be referred to by index or key.
#
# Once a set is created, you cannot change its items, but you can add new items.
#
# Sets cannot have two items with the same value.
#
#
# Constructor : set( )

# %%
thisset = {"apple", "banana", "cherry"}
print(thisset)
# Out:
# {'banana', 'cherry', 'apple'}

# %%
thisset = {"apple", "banana", "cherry", "apple"}

print(thisset)
# Out:
# {'banana', 'cherry', 'apple'}

# %%
thisset = {"apple", "banana", "cherry"}

print(len(thisset))
# Out:
# 3

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {1, 5, 7, 9, 3}
set3 = {True, False, False}
set4 = {"abc", 34, True, 40, "male"}

print(set1, set2, set3, set4)
# Out:
# {'cherry', 'apple', 'banana'} {1, 3, 5, 7, 9} {False, True} {True, 34, 40, 'abc', 'male'}

# %%
thisset = set(("apple", "banana", "cherry")) # note the double round-brackets
print(thisset)
# Out:
# {'cherry', 'apple', 'banana'}

# %% [markdown]
# ### Access Items

# %%
thisset = {"apple", "banana", "cherry"}

for x in thisset:
  print(x)
# Out:
# cherry
# apple
# banana

# %%
thisset = {"apple", "banana", "cherry"}

print("banana" in thisset)
# Out:
# True

# %% [markdown]
# ### Add Set Items

# %%
thisset = {"apple", "banana", "cherry"}

thisset.add("orange")

print(thisset)
# Out:
# {'banana', 'orange', 'cherry', 'apple'}

# %%
thisset = {"apple", "banana", "cherry"}
tropical = {"pineapple", "mango", "papaya"}

thisset.update(tropical)

print(thisset)
# Out:
# {'banana', 'cherry', 'papaya', 'pineapple', 'mango', 'apple'}

# %%
thisset = {"apple", "banana", "cherry"}
mylist = ["kiwi", "orange"]

thisset.update(mylist)

print(thisset)
# Out:
# {'banana', 'kiwi', 'orange', 'cherry', 'apple'}

# %% [markdown]
# To remove an item in a set, use the remove(), or the discard() method.

# %%
thisset = {"apple", "banana", "cherry"}

thisset.remove("banana")

print(thisset)
# Out:
# {'cherry', 'apple'}

# %%
thisset = {"apple", "banana", "cherry"}

thisset.discard("banana")

print(thisset)
# Out:
# {'cherry', 'apple'}

# %% [markdown]
# Remove the last item by using the pop() method:

# %%
thisset = {"apple", "banana", "cherry"}

x = thisset.pop()

print(x)

print(thisset)
# Out:
# banana
# {'cherry', 'apple'}

# %% [markdown]
# The clear() method empties the set:

# %%
thisset = {"apple", "banana", "cherry"}

thisset.clear()

print(thisset)
# Out:
# set()

# %% [markdown]
# Loop through the set, and print the values:

# %%
thisset = {"apple", "banana", "cherry"}

for x in thisset:
  print(x)
# Out:
# banana
# cherry
# apple

# %% [markdown]
# The union() method returns a new set with all items from both sets:

# %%
set1 = {"a", "b" , "c"}
set2 = {1, 2, 3}

set3 = set1.union(set2)
print(set3)
# Out:
# {'b', 1, 2, 3, 'a', 'c'}

# %% [markdown]
# The update() method inserts the items in set2 into set1:

# %%
set1 = {"a", "b" , "c"}
set2 = {1, 2, 3}

set1.update(set2)
print(set1)
# Out:
# {1, 2, 3, 'b', 'a', 'c'}

# %% [markdown]
# Keep the items that exist in both set x, and set y:

# %%
x = {"apple", "banana", "cherry"}
y = {"google", "microsoft", "apple"}

x.intersection_update(y)

print(x)
# Out:
# {'apple'}

# %% [markdown]
# Return a set that contains all items from both sets, except items that are present in both:

# %%
x = {"apple", "banana", "cherry"}
y = {"google", "microsoft", "apple"}

z = x.symmetric_difference(y)

print(z)
# Out:
# {'cherry', 'microsoft', 'google', 'banana'}
